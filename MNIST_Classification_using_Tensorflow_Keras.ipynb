# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from matplotlib import pyplot as plt

# %%
tf.__version__
# Out:
# '1.12.0'

# %% [markdown]
# # Import DataSet

# %%
mnist = keras.datasets.mnist
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %% [markdown]
# # Plot the images

# %%
plt.figure(num=None, figsize=(10, 10), dpi=80, facecolor='w', edgecolor='k')
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.imshow(X_train[i])

# %% [markdown]
# # Normalize Data

# %%
X_train,X_test = X_train/255.0,X_test/255.0

# %% [markdown]
# # Create Model

# %%
model = keras.models.Sequential([keras.layers.Flatten(input_shape = (28,28)),
                                 keras.layers.Dense(512,activation = tf.nn.relu),
                                keras.layers.Dropout(0.2),keras.layers.Dense(10,activation = tf.nn.softmax)])

# %% [markdown]
# # Compile and train the Model

# %%
model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
model.fit(X_train,y_train,epochs = 5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 6s 92us/step - loss: 0.2178 - acc: 0.9359
# Epoch 2/5
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0952 - acc: 0.9707
# Epoch 3/5
# 60000/60000 [==============================] - 5s 91us/step - loss: 0.0703 - acc: 0.9773
# Epoch 4/5
# 60000/60000 [==============================] - 6s 100us/step - loss: 0.0505 - acc: 0.9834
# Epoch 5/5
# 60000/60000 [==============================] - 6s 99us/step - loss: 0.0440 - acc: 0.9855

# %% [markdown]
# # Test the model

# %%
model.evaluate(X_test,y_test)
# Out:
# 10000/10000 [==============================] - 0s 36us/step
# [0.06578998362706043, 0.9796]
