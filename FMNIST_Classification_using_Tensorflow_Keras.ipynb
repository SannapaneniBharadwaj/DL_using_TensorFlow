# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from matplotlib import pyplot as plt
# Out:
# /home/bharadwaj/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf.__version__
# Out:
# '1.13.1'

# %% [markdown]
# # Import DataSet

# %%
fashion_mnist = keras.datasets.fashion_mnist
(X_train,y_train),(X_test,y_test) = fashion_mnist.load_data()

# %% [markdown]
# # Plot the images

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure(figsize=(10, 10))
for i in range(1,26):
    plt.subplot(5,5,i)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i])
    plt.xlabel(class_names[y_train[i]])

# %% [markdown]
# # Normalize Data

# %%
X_train,X_test = X_train/255.0,X_test/255.0

# %% [markdown]
# # Create Model

# %%
model = keras.models.Sequential([keras.layers.Flatten(input_shape = (28,28)),
                                 keras.layers.Dense(512,activation = tf.nn.relu),
                                keras.layers.Dropout(0.2),keras.layers.Dense(10,activation = tf.nn.softmax)])

# %% [markdown]
# # Compile and train the Model

# %%
model.compile(optimizer = 'adam',loss = 'sparse_categorical_crossentropy',metrics = ['accuracy'])

# %%
model.fit(X_train,y_train,epochs = 5)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.4962 - acc: 0.8219
# Epoch 2/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.3827 - acc: 0.8598
# Epoch 3/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.3507 - acc: 0.8715
# Epoch 4/5
# 60000/60000 [==============================] - 5s 90us/sample - loss: 0.3279 - acc: 0.8788
# Epoch 5/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.3144 - acc: 0.8829

# %% [markdown]
# # Test the model

# %%
test_loss,test_accuracy = model.evaluate(X_test,y_test)
# Out:
# 10000/10000 [==============================] - 0s 26us/sample - loss: 0.3827 - acc: 0.8605

# %%
print('Test Accuracy is',test_accuracy)
# Out:
# Test Accuracy is 0.8605
